# %% [markdown]
# # Avoid Reaver
# [링크](https://teamsaida.github.io/SAIDA_RL/AvoidReavers)
# > 3 마리의 리버를 피해서 목적지까지 운행하는 드랍쉽 학습하기

# %% [markdown]
# ## 특징
# ---
# * 리버의 움직임은 랜덤 - stochastic
# * 유닛크기에 비해서 맵의 크기가 작으므로 매 step 마다 신중히 움직여야 함
# * 시작지점 근처는 방해없이 움직일 수 있으므로 여기서 가속하는 등 잘 활용
# * action 중에서 이동거리를 적당히 잡아야 함 - 너무 짧으면 오래 걸리고, 너무 길면 맵밖으로 나가려는 시도함
#
# > `action` - `discrete(0 - 360/angle)` `continuous(x, y, type)` `continuous(theta, radian, type)`
#
# > `observation` - `base(가속도, 방어력, 최대속도 등)` `current(현재체력, 현재쉴드, 각도 등)`
#
# > `reward` - `given (맵밖에 나가거나 리버와 충돌시 부정적 보상 / 목표에 닿으면 보상)`

# %% [markdown]
# ## jupyter 에서 현재 디렉 찾는 법
# `os.path.basename('')`

# %%
my_unit {
  unit_type: "Terran_Dropship"
  hp: 150
  pos_x: 265
  pos_y: 32
  angle: 3.215223731408304
}
en_unit {
  unit_type: "Protoss_Reaver"
  hp: 100
  shield: 80
  cooldown: 8
  pos_x: 163
  pos_y: 212
  angle: 1.055378782065321
}
en_unit {
  unit_type: "Protoss_Reaver"
  hp: 100
  shield: 80
  cooldown: 10
  pos_x: 288
  pos_y: 208
  velocity_x: 1.0
  accelerating: true
}
en_unit {
  unit_type: "Protoss_Reaver"
  hp: 100
  shield: 80
  cooldown: 9
  pos_x: 289
  pos_y: 30
  velocity_x: -2.12109375
  velocity_y: 2.12109375
  angle: 2.380738182798515
  accelerating: true
}
# Out:
#   File "<ipython-input-1-e3724153ad10>", line 1
#     my_unit {
#             ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import os
import math
from datetime import datetime
from core.common.processor import Processor
from core.algorithm.REINFORCE import ReinforceAgent
from core.callbacks import DrawTrainMovingAvgPlotCallback
from saida_gym.starcraft.avoidReavers import AvoidReavers
import saida_gym.envs.conn.connection_env as Config

from keras.layers import Dense, Reshape
from keras.optimizers import Adam
from keras.models import Sequential

# %%
class ReaverProcessor(Processor):

    # Process an performed action 
    def process_action(self, action):
        "do what you want with the action"
        print('action :', action)
        return action

    # Process the data given from environment after the step finished.
    def process_step(self, observation, reward, done, info):
        state_array = self.process_observation(observation)
        reward = self.reward_reshape(reward)
        print('states :', observation)
        return state_array, reward, done, info

    # Reshape your reward (Optional)
    def reward_reshape(self, reward):
        # Maybe I can give more incentive to the agent, when the agent has reached the goal.
        if reward == 1 :  
            reward = reward * 2
        # And prevent to stay at safe start position rather then moving, give a small negative reward in every step.
        elif reward == -1 :
            reward  = -0.1
        
        return reward
    
    # Process the raw observation given from environment
    def process_observation(self, observation, **kwargs):
        # Raw observation data is the form of JSON(precisely, Protobuf).
        # Therefore, we need to transform it into an array or something can be calculated.
        
        # Define the size of state array. 
        # This time, I need 23 numbers to make the state, which consists of 5 factors of agent observation and 6 from 3 enemies one.
        #print(observation)
        STATE_SIZE = 5 + 3 * 6
        s = np.zeros(STATE_SIZE) # Make an empty array.
        return s
    
    @staticmethod
    def scale_velocity(v):
        return v

    @staticmethod
    def scale_angle(angle):
        return (angle - math.pi) / math.pi

    @staticmethod
    def scale_pos(pos):
        return int(pos / 16)

# %%
if __name__ == '__main__':
    STATE_SIZE = 5 + 3 * 6
    TRAINING_MODE = True
    FILE_NAME = os.path.basename('').split('.')[0] + "-" + datetime.now().strftime("%m%d%H%M%S")

    # todo : need to substitute it with env.make() and also remove other parameters such as protobuf_name & verbose!?
    # Create an Environment
    env = AvoidReavers(move_angle=30, move_dist=3, frames_per_step=24)
    action_size = env.action_space.n

    # Create your model
    model = Sequential()
    model.add(Dense(70, input_dim=STATE_SIZE, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(action_size, activation='softmax'))
    model.summary()

    # Create your Agent
    agent = ReinforceAgent(STATE_SIZE, action_size, processor=ReaverProcessor(), model=model,
                           discount_factor=0.9)

    agent.compile(Adam(lr=.01))

    # For the Graph
    cb_plot = DrawTrainMovingAvgPlotCallback('../../save_graph/' + FILE_NAME + '.png', 10, 5, l_label=['episode_reward'])

    # Run your agent
    agent.run(env, 10 * 100, train_mode=TRAINING_MODE, verbose=2, callbacks=[cb_plot])

    agent.save_weights(FILE_NAME + '.h5f', False)

    env.close()
# Out:
# Initialize...
# Shared Memory create
# SAIDA_AR7116 Shared memory found.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 70)                1680
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                3550
# _________________________________________________________________
# dense_8 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                1230
# _________________________________________________________________
# dense_10 (Dense)             (None, 13)                403
# =================================================================
# Total params: 8,903
# Trainable params: 8,903
# Non-trainable params: 0
# _________________________________________________________________
# Starting training for 1000 steps ...
# action : [11]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 5.915029918087033
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 70
#   pos_y: 231
#   velocity_x: -2.12109375
#   velocity_y: -2.12109375
#   angle: 3.9269908169872414
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 200
#   pos_y: 224
#   velocity_x: 0.7265625
#   velocity_y: 2.90625
#   angle: 1.3008157081270237
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 294
#   pos_y: 64
#   velocity_x: 3.0
#   accelerating: true
# }
#
# action : [4]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 5.915029918087033
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 3
#   pos_x: 39
#   pos_y: 200
#   velocity_x: -0.671875
#   velocity_y: -0.7421875
#   angle: 3.9269908169872414
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 2
#   pos_x: 208
#   pos_y: 264
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 1
#   pos_x: 304
#   pos_y: 64
# }
#
# action : [9]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 5.915029918087033
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 15
#   pos_x: 24
#   pos_y: 161
#   angle: 4.466952054322987
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 14
#   pos_x: 208
#   pos_y: 304
#   angle: 1.5707963267948966
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 13
#   pos_x: 304
#   pos_y: 64
# }
#
# action : [9]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 5.915029918087033
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown:

# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 98
#   pos_y: 218
#   velocity_x: 2.0703125
#   velocity_y: 1.3125
#   angle: 0.5399612373357456
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 112
#   pos_y: 167
#   angle: 1.5707963267948966
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 121
#   pos_y: 199
#   angle: 5.522330836388308
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 244
#   pos_y: 148
#   velocity_x: -1.95703125
#   velocity_y: -2.2734375
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [10]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 131
#   pos_y: 177
#   velocity_x: 0.9296875
#   velocity_y: -2.41796875
#   angle: 5.056000676871073
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 2
#   pos_x: 128
#   pos_y: 167
#   velocity_x: 1.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 1
#   pos_x: 142
#   pos_y: 199
#   velocity_x: 1.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 3
#   pos_x: 216
#   pos_y: 121
#   velocity_x: -0.72265625
#   velocity_y: -0.69140625
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [7]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 86
#   pos_y: 143
#   velocity_x: -2.31640625
#   velocity_y: -0.828125
#   angle: 3.485204350076177
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 153
#   pos_y: 167
#   angle: 1.5707963267948966
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 181
#   pos_y: 199
#   velocity_x: 2.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 183
#   pos_y: 87
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [12]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 47
#   pos_y: 129
#   velocity_x: -0.90234375
#   velocity_y: -0.42578125
#   angle: 3.485204350076177
#   accelerating: true
#   braking: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 5
#   pos_x: 153
#   pos_y: 193
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 156
#   pos_y: 60
#   velocity_x: -2.12109375
#   velocity_y: -2.12109375
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 4
#   pos_x: 185
#   pos_y: 171
#   angle: 4.71238898038469
#   accelerating: true
# }
#
# action : [4]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 141
#   angle: 1.2762720155208536
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 125
#   pos_y: 30
#   velocity_x: -0.69140625
#   velocity_y: -0.72265625
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 153
#   pos_y: 233
#   velocity_y: 2.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 188
#   pos_y: 133
#   velocity_x: 0.72265625
#   velocity_y: -0.69140625
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [9]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 42
#   pos_y: 127
#   velocity_x: -0.03515625
#   velocity_y: -1.39453125
#   angle: 4.6878452877785195
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 112
#   pos_y: 16
#   angle: 3.902447124381071
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 153
#   pos_y: 279
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 217
#   pos_y: 104
#   velocity_x: 1.4140625
#   velocity_y: -1.4140625
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [11]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 83
#   pos_y: 100
#   velocity_x: 2.3359375
#   velocity_y: -1.10546875
#   angle: 5.841398840268521
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 5
#   pos_x: 128
#   pos_y: 300
#   velocity_x: -0.96875
#   velocity_y: 0.2421875
#   angle: 2.945243112740431
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 142
#   pos_y: 16
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 4
#   pos_x: 249
#   pos_y: 71
#   angle: 5.915029918087033
#   accelerating: true
# }
#
# action : [8]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 67
#   pos_y: 56
#   velocity_x: -1.45703125
#   velocity_y: -1.45703125
#   angle: 3.9269908169872414
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x:
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 1
#   pos_x: 112
#   pos_y: 77
#   velocity_y: 2.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 2
#   pos_x: 144
#   pos_y: 176
#   angle: 5.522330836388308
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 3
#   pos_x: 162
#   pos_y: 259
#   velocity_x: -0.70703125
#   velocity_y: -0.70703125
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [6]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 3.043417883165112
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 13
#   pos_x: 112
#   pos_y: 119
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 15
#   pos_x: 132
#   pos_y: 228
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 14
#   pos_x: 173
#   pos_y: 147
#   velocity_x: 0.72265625
#   velocity_y: -0.69140625
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [6]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 3.043417883165112
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 105
#   pos_y: 202
#   velocity_x: -2.12109375
#   velocity_y: -2.12109375
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 112
#   pos_y: 161
#   velocity_y: 6.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 202
#   pos_y: 118
#   velocity_x: 1.4453125
#   velocity_y: -1.3828125
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [4]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 3.043417883165112
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 3
#   pos_x: 98
#   pos_y: 195
#   velocity_x: -0.69140625
#   velocity_y: -0.72265625
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 1
#   pos_x: 132
#   pos_y: 167
#   velocity_x: 2.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 2
#   pos_x: 231
#   pos_y: 89
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [7]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 3.043417883165112
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 69
#   pos_y: 165
#   velocity_x: -4.3359375
#   velocity_y: -4.1484375
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 134
#   pos_y: 204
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 260
#   pos_y: 61
#   velocity_x: 0.69140625
#   velocity_y: -0.72265625
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [8]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 32
#   angle: 3.043417883165112
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 38
#   pos_y: 135
#   velocity_x: -1.4140625
#   velocity_y: -1.4140625
#   angle: 3.902447124381071
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 4
#   pos_x: 134
#   pos_y: 241
#   velocity_y: 6.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 5
# ...
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 14
#   pos_x: 16
#   pos_y: 304
#   angle: 1.5707963267948966
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 13
#   pos_x: 48
#   pos_y: 224
#   velocity_y: -1.0
#   angle: 4.71238898038469
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 15
#   pos_x: 228
#   pos_y: 132
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [0]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 149
#   pos_y: 140
#   velocity_x: 2.1796875
#   velocity_y: -0.1640625
#   angle: 6.234097921967246
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 40
#   pos_y: 304
#   velocity_x: 1.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 48
#   pos_y: 182
#   velocity_y: -6.0
#   angle: 4.71238898038469
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 201
#   pos_y: 106
#   velocity_x: -2.12109375
#   velocity_y: -2.12109375
#   angle: 3.902447124381071
#   accelerating: true
# }
#
# action : [0]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 208
#   pos_y: 140
#   velocity_x: 2.32421875
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 1
#   pos_x: 31
#   pos_y: 143
#   velocity_x: -0.8984375
#   velocity_y: -1.7890625
#   angle: 4.246058820867455
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown:
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 271
#   pos_y: 176
#   angle: 2.675262494072558
# }
#
# action : [5]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 143
#   pos_y: 263
#   velocity_x: -1.9375
#   velocity_y: 1.03515625
#   angle: 2.675262494072558
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 4
#   pos_x: 214
#   pos_y: 208
#   velocity_x: -6.0
#   angle: 3.141592653589793
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 252
#   pos_y: 186
#   velocity_x: -1.8046875
#   velocity_y: 0.8515625
#   angle: 2.675262494072558
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 5
#   pos_x: 278
#   pos_y: 105
#   velocity_x: 0.72265625
#   velocity_y: -0.69140625
#   angle: 5.522330836388308
#   accelerating: true
# }
#
# action : [5]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 82
#   pos_y: 275
#   velocity_x: -2.82421875
#   velocity_y: 0.421875
#   angle: 2.9943304979527716
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 208
#   pos_y: 244
#   velocity_y: 2.0
#   angle: 1.5462526341887264
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 221
#   pos_y: 201
#   velocity_x: -0.8828125
#   velocity_y: 0.47265625
#   angle: 2.675262494072558
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 304
#   pos_y: 80
#   angle: 5.522330836388308
# }
#
# action : [7]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 42
#   pos_y: 252
#   velocity_x: -0.9140625
#   velocity_y: -0.875
#   angle: 3.80427235395639
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 208
#   pos_y: 240
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 208
#   pos_y: 288
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 293
#   pos_y: 89
#   velocity_x: -1.4140625
#   velocity_y: 1.4140625
#   angle: 2.356194490192345
#   accelerating: true
# }
#
# action : [0]
# states : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 69
#   pos_y: 244
#   velocity_x: 2.4453125
#   velocity_y: 0.23828125
#   angle: 0.09817477042468103
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 208
#   pos_y: 272
#   angle: 1.5707963267948966
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 4
#   pos_x: 208
#   pos_y: 304
#   velocity_x: -0.83203125
#   velocity_y: 0.5546875
#   angle: 2.552544031041707
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 5
#   pos_x: 261
#   pos_y: 122
#   angle: 2.356194490192345
#   accelerating: true
# }
#
# action : [10]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-6f74fb413cd9> in <module>
#      28
#      29     # Run your agent
# ---> 30     agent.run(env, 10 * 100, train_mode=TRAINING_MODE, verbose=2, callbacks=[cb_plot])
#      31
#      32     agent.save_weights(FILE_NAME + '.h5f', False)
#
# ~\SAIDA_RL\python\core\common\agent.py in run(self, env, nb_steps, shared_cb_params, train_mode, action_repetition, callbacks, verbose, visualize, nb_max_start_steps, random_policy, log_interval, nb_max_episode_steps, nb_episodes)
#     191
#     192                 callbacks.on_action_begin(action)
# --> 193                 observation, r, done, info = env.step(action)
#     194                 observation = deepcopy(observation)
#     195                 if self.processor is not None:
#
# ~\SAIDA_RL\python\saida_gym\envs\SAIDAGym.py in step(self, action, **kwargs)
#     124         self.conn.write(env.MESSAGE_TYPE["Step"], self.make_step_msg(self.step_req_msg, action, **kwargs))
#     125
# --> 126         step_val = self.conn.read()
#     127
#     128         if step_val[0] != "Step":
#
# ~\SAIDA_RL\python\saida_gym\envs\conn\shm.py in read(self, end_on_close)
#      67             self.shm.seek(0)
#      68             msg = self.shm.read(1).decode('ascii')
# ---> 69             sleep(0.001)
#      70             sleepTime += 0.001
#      71             # if sleepTime > 30 :
#
# KeyboardInterrupt:
