# %%
# Copyright (C) 2019 SAMSUNG SDS <Team.SAIDA@gmail.com>
#
# This code is distribued under the terms and conditions from the MIT License (MIT).
#
# Authors : Uk Jo, Iljoo Yoon, Hyunjae Lee, Daehun Jun

# Initial framework taken from https://github.com/jaara/AI-blog/blob/master/CartPole-A3C.py

from core.algorithm.PPO import PPOAgent
import numpy as np
import os
from datetime import datetime
from core.common.processor import Processor
from saida_gym.starcraft.avoidReavers import AvoidReavers
from core.callbacks import DrawTrainMovingAvgPlotCallback
import saida_gym.envs.conn.connection_env as Config
from keras.models import Model
from keras.layers import Input, Dense
from keras.optimizers import Adam
import math

import argparse
from core.common.util import OPS
import math

# %%
'''parser = argparse.ArgumentParser(description='PPO Configuration for Avoid_Reaver')

parser.add_argument(OPS.NO_GUI.value, help='gui', type=bool, default=False)
parser.add_argument(OPS.MOVE_ANG.value, help='move angle', default=10, type=int)
parser.add_argument(OPS.MOVE_ANG.value, help='move dist', default=2, type=int)
parser.add_argument(OPS.GAMMA.value, help='gamma', default=0.99, type=float)
parser.add_argument(OPS.EPOCHS.value, help='Epochs', default=10, type=int)
#args = parser.parse_args()
#dict_args = vars(args)
dict_args = {OPS.NO_GUI.value:False, OPS.MOVE_ANG.value:10, OPS.MOVE_ANG.value:2, OPS.GAMMA.value:.99, OPS.EPOCHS.value:10}

post_fix = ''
for k in dict_args.keys():
    if k == OPS.NO_GUI():
        continue
    post_fix += '_' + k + '_' + str(dict_args[k])
'''
# Hyper param
NO_GUI = False #dict_args[OPS.NO_GUI()]
NB_STEPS = 50000
STATE_SIZE = 8 + 3 * 8
LOSS_CLIPPING = 0.2  # Only implemented clipping for the surrogate loss, paper said it was best
EPOCHS = 10 #dict_args[OPS.EPOCHS()]
NOISE = 0.1  # Exploration noise
GAMMA = .99 #dict_args[OPS.GAMMA()]
BUFFER_SIZE = 256
BATCH_SIZE = 64
HIDDEN_SIZE = 80
NUM_LAYERS = 3
ENTROPY_LOSS = 1e-3
LR = 1e-4  # Lower lr stabilises training greatly


def scale_velocity(v):
    return v


def scale_angle(angle):
    return (angle - math.pi) / math.pi


def scale_pos(pos):
    return pos / 16


def scale_pos2(pos):
    return pos / 8


def exponential_average(old, new, b1):
    return old * b1 + (1-b1) * new


# Reshape the reward in a way you want
def reward_reshape(reward):
    """ Reshape the reward
        Starcraft Env returns the reward according to following conditions.
        1. Invalid action : -0.1
        2. get hit : -1
        3. goal : 1
        4. others : 0

    # Argument
        reward (float): The observed reward after executing the action

    # Returns
        reshaped reward
    """

    if math.fabs(reward + 0.1) < 0.01:
        reward = -1
    elif reward == -1:
        reward = -10
    elif reward == 1:
        reward = 10
    elif reward == 0:
        reward = -0.1

    return reward


class ReaverProcessor(Processor):
    def __init__(self):
        self.last_action = None
        self.success_cnt = 0
        self.cumulate_reward = 0

    def process_action(self, action):
        self.last_action = action
        return action

    def process_step(self, observation, reward, done, info):
        print('original observation :', observation)
        state_array = self.process_observation(observation)
        print('modified observation :', state_array)
        reward = self.process_reward(reward, observation)
        print('modified reward :', reward)
        #reward = reward_reshape(reward)
        self.cumulate_reward += reward

        if reward == 10:
            if self.cumulate_reward > 0:
                self.success_cnt += 1

            self.cumulate_reward = 0
            print("success_cnt = ", self.success_cnt)

        return state_array, reward, done, info

    def process_observation(self, observation, **kwargs):
        """ Pre-process observation

        # Argument
            observation (object): The current observation from the environment.

        # Returns
            processed observation

        """
        if len(observation.my_unit) > 0:
            s = np.zeros(STATE_SIZE)
            me = observation.my_unit[0]
            # Observation for Dropship
            s[0] = scale_pos2(me.pos_x)  # X of coordinates
            s[1] = scale_pos2(me.pos_y)  # Y of coordinates
            s[2] = scale_pos2(me.pos_x - 320)  # relative X of coordinates from goal
            s[3] = scale_pos2(me.pos_y - 320)  # relative Y of coordinates from goal
            s[4] = scale_velocity(me.velocity_x)  # X of velocity
            s[5] = scale_velocity(me.velocity_y)  # y of coordinates
            s[6] = scale_angle(me.angle)  # Angle of head of dropship
            s[7] = 1 if me.accelerating else 0  # True if Dropship is accelerating

            # Observation for Reavers
            for ind, ob in enumerate(observation.en_unit):
                s[ind * 8 + 8] = scale_pos2(ob.pos_x - me.pos_x)  # X of relative coordinates
                s[ind * 8 + 9] = scale_pos2(ob.pos_y - me.pos_y)  # Y of relative coordinates
                s[ind * 8 + 10] = scale_pos2(ob.pos_x - 320)  # X of relative coordinates
                s[ind * 8 + 11] = scale_pos2(ob.pos_y - 320)  # Y of relative coordinates
                s[ind * 8 + 12] = scale_velocity(ob.velocity_x)  # X of velocity
                s[ind * 8 + 13] = scale_velocity(ob.velocity_y)  # Y of velocity
                s[ind * 8 + 14] = scale_angle(ob.angle)  # Angle of head of Reavers
                s[ind * 8 + 15] = 1 if ob.accelerating else 0  # True if Reaver is accelerating

        return s
    
    def process_reward(self, reward, observation):
        me = observation.my_unit[0]
        reward = reward + pow(me.pos_x,2) + pow(me.pos_y,2)
        return reward


def build_actor(state_size, action_size, advantage, old_prediction):
    state_input = Input(shape=(state_size,))

    x = Dense(HIDDEN_SIZE, activation='tanh')(state_input)
    for _ in range(NUM_LAYERS - 1):
        x = Dense(HIDDEN_SIZE, activation='tanh')(x)

    out_actions = Dense(action_size, activation='softmax', name='output')(x)

    model = Model(inputs=[state_input, advantage, old_prediction], outputs=[out_actions])

    return model


def build_actor_continuous(state_size, action_size, advantage, old_prediction):

    state_input = Input(shape=(state_size,))
    x = Dense(HIDDEN_SIZE, activation='tanh')(state_input)

    for _ in range(NUM_LAYERS - 1):
        x = Dense(HIDDEN_SIZE, activation='tanh')(x)

    out_actions = Dense(action_size, name='output', activation='tanh')(x)

    model = Model(inputs=[state_input, advantage, old_prediction], outputs=[out_actions])

    return model


def build_critic(state_size):

    state_input = Input(shape=(state_size,))
    x = Dense(HIDDEN_SIZE, activation='tanh')(state_input)
    for _ in range(NUM_LAYERS - 1):
        x = Dense(HIDDEN_SIZE, activation='tanh')(x)

    out_value = Dense(1)(x)

    model = Model(inputs=[state_input], outputs=[out_value])

    return model

# %%
if __name__ == '__main__':
    training_mode = True
    load_model = False
    FILE_NAME = os.path.basename('').split('.')[0] + "-" + datetime.now().strftime("%m%d%H%M%S")
    action_type = 0

    env = AvoidReavers(move_angle=10, move_dist=2, frames_per_step=16
                       , verbose=0, action_type=action_type, no_gui=NO_GUI)
    
    print('action - ', env.action_space)
    ACTION_SIZE = env.action_space.n

    continuous = False if action_type == 0 else True

    # Build models
    actor = None
    ADVANTAGE = Input(shape=(1,))
    OLD_PREDICTION = Input(shape=(ACTION_SIZE,))

    if continuous:
        actor = build_actor_continuous(STATE_SIZE, ACTION_SIZE, ADVANTAGE, OLD_PREDICTION)
    else:
        actor = build_actor(STATE_SIZE, ACTION_SIZE, ADVANTAGE, OLD_PREDICTION)

    critic = build_critic(STATE_SIZE)

    agent = PPOAgent(STATE_SIZE, ACTION_SIZE, continuous, actor, critic, GAMMA, LOSS_CLIPPING, EPOCHS, NOISE, ENTROPY_LOSS,
                     BUFFER_SIZE,BATCH_SIZE, processor=ReaverProcessor())

    agent.compile(optimizer=[Adam(lr=LR), Adam(lr=LR)], metrics=[ADVANTAGE, OLD_PREDICTION])

    cb_plot = DrawTrainMovingAvgPlotCallback(os.path.realpath(''), 10, 5, l_label=['episode_reward'])

    agent.run(env, NB_STEPS, train_mode=training_mode, verbose=2, callbacks=[cb_plot], action_repetition=1, nb_episodes=1000)

    if training_mode:
        agent.save_weights(os.path.realpath("../../save_model"),"avoid_Reavers_PPO")

    env.close()
# Out:
# Initialize...
# Shared Memory create
# SAIDA_AR7624 Shared memory found.
# action -  Discrete(37)
# observation - None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_51 (InputLayer)        (None, 32)                0
# _________________________________________________________________
# dense_85 (Dense)             (None, 80)                2640
# _________________________________________________________________
# dense_86 (Dense)             (None, 80)                6480
# _________________________________________________________________
# dense_87 (Dense)             (None, 80)                6480
# _________________________________________________________________
# output (Dense)               (None, 37)                2997
# =================================================================
# Total params: 18,597
# Trainable params: 18,597
# Non-trainable params: 0
# _________________________________________________________________
# Starting training for 50000 steps ...
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 40
#   pos_y: 34
#   velocity_x: 0.8515625
#   velocity_y: -0.12890625
#   angle: 6.1850105367549055
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 96
#   pos_y: 281
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   pos_x: 216
#   pos_y: 197
#   velocity_x: 0.96875
#   velocity_y: 0.2421875
#   angle: 0.22089323345553233
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 15
#   pos_x: 231
#   pos_y: 64
#   velocity_x: -1.0
#   angle: 3.141592653589793
#   accelerating: true
# }
#
# modified observation : [  5.           4.25       -35.         -35.75         0.8515625
#   -0.12890625   0.96875      1.           7.          30.875
#  -28.          -4.875        0.           1.          -0.5
#    1.          22.          20.375      -13.         -15.375
#    0.96875      0.2421875   -0.9296875    1.          23.875
#    3.75       -11.125      -32.          -1.           0.
#    0.           1.        ]
# modified reward : 2756.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 43
#   pos_y: 40
#   velocity_x: -0.99609375
#   velocity_y: 0.01953125
#   angle: 4.0987966652304335
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown:
0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 261
#   pos_y: 72
#   velocity_x: 1.6015625
#   velocity_y: -0.44140625
#   angle: 5.988660995905543
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 16
#   pos_y: 252
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 12
#   pos_x: 232
#   pos_y: 136
#   angle: 0.760854470791278
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 13
#   pos_x: 280
#   pos_y: 183
#   velocity_x: 4.3359375
#   velocity_y: 4.1484375
#   angle: 0.760854470791278
#   accelerating: true
# }
#
# modified observation : [ 32.625        9.          -7.375      -31.           1.6015625
#   -0.44140625   0.90625      1.         -30.625       22.5
#  -38.          -8.5          0.           0.          -0.5
#    1.          -3.625        8.         -11.         -23.
#    0.           0.          -0.7578125    1.           2.375
#   13.875       -5.         -17.125        4.3359375    4.1484375
#   -0.7578125    1.        ]
# modified reward : 73304.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 266
#   pos_y: 86
#   velocity_x: -2.25390625
#   velocity_y: 0.5625
#   angle: 2.8961557275280905
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 13
# ...
# modified reward : 46280.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 81
#   pos_y: 169
#   velocity_x: -0.48046875
#   velocity_y: -2.140625
#   angle: 4.491495746929157
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 48
#   pos_y: 119
#   angle: 3.8533597391687304
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 112
#   pos_y: 192
#   velocity_y: 2.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 6
#   pos_x: 304
#   pos_y: 87
#   angle: 1.5707963267948966
#   accelerating: true
# }
#
# modified observation : [ 10.125       21.125      -29.875      -18.875       -0.48046875
#   -2.140625     0.4296875    1.          -4.125       -6.25
#  -34.         -25.125        0.           0.           0.2265625
#    0.           3.875        2.875      -26.         -16.
#    0.           2.          -0.5          1.          27.875
#  -10.25        -2.         -29.125        0.           0.
#   -0.5          1.        ]
# modified reward : 35121.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 57
#   pos_y: 157
#   velocity_x: -1.65625
#   velocity_y: -0.125
#   angle: 3.1906800388021335
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 26
#   pos_y: 114
#   velocity_x: -2.9296875
#   velocity_y: -0.65625
#   angle: 3.3379421944391554
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 112
#   pos_y: 222
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 304
#   pos_y: 112
#   velocity_y: 1.0
#   angle: 1.5707963267948966
#   accelerating: true
# }
#
# modified observation : [ 7.1250000e+00  1.9625000e+01 -3.2875000e+01 -2.0375000e+01
#  -1.6562500e+00 -1.2500000e-01  1.5625000e-02  1.0000000e+00
#  -3.8750000e+00 -5.3750000e+00 -3.6750000e+01 -2.5750000e+01
#  -2.9296875e+00 -6.5625000e-01  6.2500000e-02  1.0000000e+00
#   6.8750000e+00  8.1250000e+00 -2.6000000e+01 -1.2250000e+01
#   0.0000000e+00  1.0000000e+00 -5.0000000e-01  1.0000000e+00
#   3.0875000e+01 -5.6250000e+00 -2.0000000e+00 -2.6000000e+01
#   0.0000000e+00  1.0000000e+00 -5.0000000e-01  1.0000000e+00]
# modified reward : 27898.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 43
#   pos_y: 170
#   velocity_x: -0.359375
#   velocity_y: 0.9296875
#   angle: 1.9634954084936207
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 16
#   pos_y: 112
#   angle: 3.3379421944391554
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown:
0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 98
#   pos_y: 162
#   velocity_x: -2.32421875
#   velocity_y: -0.0546875
#   angle: 3.1906800388021335
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 40
#   pos_y: 304
#   velocity_x: 1.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 48
#   pos_y: 186
#   velocity_y: -3.0
#   angle: 4.71238898038469
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 7
#   pos_x: 278
#   pos_y: 208
#   velocity_x: -6.0
#   angle: 3.141592653589793
#   accelerating: true
# }
#
# modified observation : [ 1.22500000e+01  2.02500000e+01 -2.77500000e+01 -1.97500000e+01
#  -2.32421875e+00 -5.46875000e-02  1.56250000e-02  1.00000000e+00
#  -7.25000000e+00  1.77500000e+01 -3.50000000e+01 -2.00000000e+00
#   1.00000000e+00  0.00000000e+00 -1.00000000e+00  1.00000000e+00
#  -6.25000000e+00  3.00000000e+00 -3.40000000e+01 -1.67500000e+01
#   0.00000000e+00 -3.00000000e+00  5.00000000e-01  1.00000000e+00
#   2.25000000e+01  5.75000000e+00 -5.25000000e+00 -1.40000000e+01
#  -6.00000000e+00  0.00000000e+00  0.00000000e+00  1.00000000e+00]
# modified reward : 35848.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 64
#   pos_y: 152
#   velocity_x: -1.81640625
#   velocity_y: -0.6484375
#   angle: 3.485204350076177
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 11
#   pos_x: 39
#   pos_y: 159
#   velocity_x: -0.8984375
#   velocity_y: -1.7890625
#   angle: 4.246058820867455
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 67
#   pos_y: 304
#   velocity_x: 2.0
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 250
#   pos_y: 208
#   velocity_x: -3.0
#   angle: 3.141592653589793
#   accelerating: true
# }
#
# modified observation : [  8.          19.         -32.         -21.          -1.81640625
#   -0.6484375    0.109375     1.          -3.125        0.875
#  -35.125      -20.125       -0.8984375   -1.7890625    0.3515625
#    1.           0.375       19.         -31.625       -2.
#    2.           0.          -1.           1.          23.25
#    7.          -8.75       -14.          -3.           0.
#    0.           1.        ]
# modified reward : 27199.0
# original observation : my_unit {
#   unit_type: "Terran_Dropship"
#   hp: 150
#   pos_x: 70
#   pos_y: 134
#   velocity_x: 2.58984375
#   velocity_y: -0.0625
#   angle: 6.258641614573416
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 10
#   pos_x: 26
#   pos_y: 133
#   velocity_x: -0.44921875
#   velocity_y: -0.89453125
#   angle: 4.246058820867455
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 9
#   pos_x: 91
#   pos_y: 293
#   velocity_x: 0.72265625
#   velocity_y: -0.69140625
#   angle: 5.522330836388308
#   accelerating: true
# }
# en_unit {
#   unit_type: "Protoss_Reaver"
#   hp: 100
#   shield: 80
#   cooldown: 8
#   pos_x: 222
#   pos_y: 208
#   velocity_x: -2.0
#   angle: 3.141592653589793
#   accelerating: true
# }
#
# modified observation : [  8.75        16.75       -31.25       -23.25         2.58984375
#   -0.0625       0.9921875    1.          -5.5         -0.125
#  -36.75       -23.375       -0.44921875  -0.89453125   0.3515625
#    1.           2.625       19.875      -28.625       -3.375
#    0.72265625  -0.69140625   0.7578125    1.          19.
#    9.25       -12.25       -14.          -2.           0.
#    0.           1.        ]
# modified reward : 22856.0
# close msg is received.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
